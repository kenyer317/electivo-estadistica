# %% [markdown]
# # Carga de datos en R

# %% [markdown]
# ## Datos Desde Archivo CSV (.csv)
# ### Comando `read.csv(<ruta de archivo>)`

# %%
datos = read.csv("ventas_electronica.csv")
datos
# Out:
#     ID_Venta      Fecha          Producto   Categoria Cantidad Precio_Unitario Descuento_Aplicado Total_Venta   Canal_Venta        Metodo_Pago
# 1       1001 2023-01-01        Smartphone       Móvil        5          407.67               0.00     2038.35 Tienda Física       Mercado Pago
# 2       1002 2023-01-03            Laptop Computación        2          871.24               0.15     1481.11           App       Mercado Pago
# 3       1003 2023-01-05  Teclado Mecánico Periféricos        4          627.87               0.00     2511.48 Tienda Física       Mercado Pago
# 4       1004 2023-01-07            Laptop Computación        2         1180.04               0.10     2124.07        Online           Efectivo
# 5       1005 2023-01-09           Monitor Computación        4          537.75               0.10     1935.90        Online           Efectivo
# ...

# %% [markdown]
# ## Desde Archivo Excel (.xlsx)
# ### 1. Instalar la libreria  Readxl (sólo una vez): comando `install.packages("readxl")`

# %%
install.packages("readxl")
# Out:
# Installing package into ‘C:/Users/Soporte/AppData/Local/R/win-library/4.5’
# (as ‘lib’ is unspecified)
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/4.5/readxl_1.4.5.zip'
# Content type 'application/zip' length 765500 bytes (747 KB)
# downloaded 747 KB
# package ‘readxl’ successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Soporte\AppData\Local\Temp\RtmpK6J005\downloaded_packages

# %% [markdown]
# ### 2. Cargar librería y leer archivo

# %%
library(readxl)
datos2= read_excel("ventas_excel.xlsx")
datos2
# Out:
# # A tibble: 1,000 × 10
#    ID_Venta Fecha               Producto         Categoria   Cantidad Precio_Unitario Descuento_Aplicado Total_Venta Canal_Venta   Metodo_Pago
#       <dbl> <dttm>              <chr>            <chr>          <dbl>           <dbl>              <dbl>       <dbl> <chr>         <chr>
#  1     1001 2023-01-01 00:00:00 Smartphone       Móvil              5            408.               0          2038. Tienda Física Mercado Pago
#  2     1002 2023-01-03 00:00:00 Laptop           Computación        2            871.               0.15       1481. App           Mercado Pago
#  3     1003 2023-01-05 00:00:00 Teclado Mecánico Periféricos        4            628.               0          2511. Tienda Física Mercado Pago
#  4     1004 2023-01-07 00:00:00 Laptop           Computación        2           1180.               0.1        2124. Online        Efectivo
# ...

# %% [markdown]
# ## Acceso a columnna específica
# ### `<nombre_datos>$<nombre_columna>`

# %%
datos$Producto
# Out:
#    [1] "Smartphone"        "Laptop"            "Teclado Mecánico"  "Laptop"            "Monitor"           "Tablet"            "Smartphone"        "Cámara Web"
#    [9] "Audífonos"         "Laptop"            "Laptop"            "Monitor"           "Laptop"            "Audífonos"         "Monitor"           "Tablet"
#   [17] "Audífonos"         "Laptop"            "Reloj Inteligente" "Audífonos"         "Cámara Web"        "Teclado Mecánico"  "Smartphone"        "Teclado Mecánico"
#   [25] "Reloj Inteligente" "Cámara Web"        "Reloj Inteligente" "Teclado Mecánico"  "Smartphone"        "Tablet"            "Tablet"            "Smartphone"
#   [33] "Smartphone"        "Laptop"            "Teclado Mecánico"  "Smartphone"        "Smartphone"        "Tablet"            "Smartphone"        "Monitor"
#   [41] "Monitor"           "Cámara Web"        "Smartphone"        "Tablet"            "Cámara Web"        "Cámara Web"        "Teclado Mecánico"  "Audífonos"
# ...
